# %%
import fasttext
from huggingface_hub import hf_hub_download

def detect_language(text):
    model_path = hf_hub_download(repo_id="facebook/fasttext-language-identification", filename="model.bin")
    model = fasttext.load_model(model_path)

    predictions = model.predict(text, k=5)

    for prediction in predictions:
        label = prediction[0]
        if label in ("__label__eng_Latn", "__label__urd_Arab"):
            return label.replace("__label__", "")
    return "Roman Urdu"

# %%
import requests
import json
import pandas as pd
import time

df = pd.read_csv('whatsapp_data.csv')
df
# Out:
#       Unnamed: 0                                           Sentence  \
# 0              0  ID 780 - Muhammad AfzalRider\nPhone\n+92300489...
# 1              1  cs order k bry men jannna chah rhy thy or call...
# 2              2  cs cmplet info fraham nhi ker pay or onko sahi...
# 3              3  cs unrechble hy or ride loaction per tha or os...
# 4              4  S156D9 sbp  still pending order confirmatrion ...
# ...          ...                                                ...
# 2549        2549      A9AL10 \ customer ko order cancel nhi karwana
# 2550        2550                  DFL65R \ guided delivery timeline
# 2551        2551                  INV886 \ guided delivery timeline
# 2552        2552                 4I7L99 \ guided delivery timeline
# 2553        2553  03151601995 \ 03036647962 As per customer unhy...
#
#         language stopwords count                            Actionable Words  \
# ...

# %%
text = df['Sentence']

# %%
url = "http://127.0.0.1:5000/predict"
for i,j in enumerate(text):
  payload = json.dumps({
    "text": j
  })
  headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer 940809d05631dea13edae629a420fdd9'
  }
  start_time = time.time()
  response = requests.request("POST", url, headers=headers, data=payload)
  end_time = time.time()
  response_time = end_time - start_time
  print(f"Response time: {response_time} seconds")

  print(response.text+" "+str(i))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File d:\work\Anaconda\envs\main\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File d:\work\Anaconda\envs\main\Lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File d:\work\Anaconda\envs\main\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
import requests
import json
import pandas as pd
import time
url = "http://127.0.0.1:5000/predict"
text = "ye kia hora h"
payload = json.dumps({
    "text": text
})
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer 940809d05631dea13edae629a420fdd9'
}
start_time = time.time()
response = requests.request("POST", url, headers=headers, data=payload)
end_time = time.time()
response_time = end_time - start_time
print(f"Response time: {response_time} seconds")

print(response.text+" "+str(text))
